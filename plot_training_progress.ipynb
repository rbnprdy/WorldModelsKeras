# %% [markdown]
# # Notebook to plot training progress of agent
#
# It will obtain data from file stored in format like `bullet_racecar.cma.1.32.hist.json` and `.hist_best.json`, where format is `env_name.optimizer.num_rollouts.popsize.hist.json`.

# %%
import numpy as np
import json
import os
import matplotlib.pyplot as plt

# %% [markdown]
# #### Set these variables to indicate which environment to use

# %%
env_name = 'car_racing'
optimizer = 'cma'
num_rollouts = 1 # number of rollouts that are averaged over an episode
popsize = 4
base_path = 'environments/carracing/log/'

# %%
file_base = env_name+'.'+optimizer+'.'+str(num_rollouts)+'.'+str(popsize)
filename = os.path.join(base_path, file_base + '.hist.json')
with open(filename, 'r') as f:
    raw_data = json.load(f)
data = np.array(raw_data)
print(data.shape)
# Out:
# (5560, 9)

# %%
required_score = 900.0
file_base = env_name+'.'+optimizer+'.'+str(num_rollouts)+'.'+str(popsize)
filename = os.path.join(base_path, file_base + '.hist_best.json')
with open(filename, 'r') as f:
    raw_data = json.load(f)
raw_best_data = np.array(raw_data)
print(raw_best_data.shape)
best_data = []
for bdata in raw_best_data:
    best_data.append([float(bdata[0]), float(bdata[1]), float(bdata[5]), float(bdata[9]), required_score])
best_data = np.array(best_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-5af391a1dfbf> in <module>
#       2 file_base = env_name+'.'+optimizer+'.'+str(num_rollouts)+'.'+str(popsize)
#       3 filename = os.path.join('log', file_base+'.hist_best.json')
# ----> 4 with open(filename, 'r') as f:
#       5   raw_data = json.load(f)
#       6 raw_best_data = np.array(raw_data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'log/car_racing.cma.1.4.hist_best.json'

# %%
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
line_mean, = plt.plot(data[:, 1]/(60*24*60), data[:, 2])
line_min, = plt.plot(data[:, 1]/(60*24*60), data[:, 3])
line_max, = plt.plot(data[:, 1]/(60*24*60), data[:, 4])
# line_best, = plt.plot(best_data[:, 1]/(60*24*60), best_data[:, 2])
line_req, = plt.plot(best_data[:, 1]/(60*24*60), best_data[:, 4])
plt.legend([line_mean, line_min, line_max, line_req], ['mean', 'min', 'max', 'requirement'])
plt.xlabel('wall-clock time (days)')
plt.xticks(np.arange(0, 3, 1))
plt.ylabel('cumulative reward')
plt.yticks(np.arange(-100, 1000, 50))
plt.title(file_base)
plt.savefig(file_base+".wall.svg")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-f935b9722bbd> in <module>
#       5 # line_best, = plt.plot(best_data[:, 1]/(60*24*60), best_data[:, 2])
#       6 # line_req, = plt.plot(best_data[:, 1]/(60*24*60), best_data[:, 4])
# ----> 7 plt.legend([line_mean, line_min, line_max, line_req], ['mean', 'min', 'max', 'requirement'])
#       8 plt.xlabel('wall-clock time (days)')
#       9 plt.xticks(np.arange(0, 3, 1))
#
# NameError: name 'line_req' is not defined

# %%
fig=plt.figure(figsize=(16, 10), dpi= 80, facecolor='w', edgecolor='k')
line_mean, = plt.plot(data[:, 0], data[:, 2])
line_min, = plt.plot(data[:, 0], data[:, 3])
line_max, = plt.plot(data[:, 0], data[:, 4])
line_best, = plt.plot(best_data[:, 0], best_data[:, 2])
line_req, = plt.plot(best_data[:, 0], best_data[:, 4])
plt.legend([line_mean, line_min, line_max, line_req, line_best], ['mean', 'min', 'max', 'requirement', 'best avg score'])
plt.xlabel('generation')
plt.xticks(np.arange(0, 2000, 200))
plt.ylabel('cumulative reward')
plt.yticks(np.arange(-100, 1000, 50))
plt.title(file_base)
plt.savefig(file_base+".svg")
plt.show()
